# %% [markdown]
# <a href="https://colab.research.google.com/github/MetaKate/CSEL-302/blob/main/2B_MACASAET_EXER2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Data Loading

# %%
data = pd.read_csv('hardwareStore.csv')
data.head()
# Out:
#    CATEGORY_ID CATEGORY_NAME  PRODUCT_ID           PRODUCT_NAME  \
# 0            1           CPU           8  Intel Xeon E5-1650 V4
# 1            1           CPU           8  Intel Xeon E5-1650 V4
# 2            1           CPU           8  Intel Xeon E5-1650 V4
# 3            1           CPU           8  Intel Xeon E5-1650 V4
# 4            1           CPU           8  Intel Xeon E5-1650 V4
#
#                      DESCRIPTION DESCRIPTION - Detail 1  \
# 0  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
# 1  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
# 2  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
# 3  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
# 4  Speed:3.6GHz,Cores:6,TDP:140W           Speed:3.6GHz
#
#   DESCRIPTION - Detail 2 DESCRIPTION - Detail 3 DESCRIPTION - Detail 4  \
# 0                Cores:6               TDP:140W                    NaN
# 1                Cores:6               TDP:140W                    NaN
# ...

# %% [markdown]
# 2. Initial Data Analysis

# %%
hardware = data.groupby('CATEGORY_NAME')['QUANTITY'].sum()

standard_cost_mean = data['STANDARD_COST'].mean()
standard_cost_median = data['STANDARD_COST'].median()
standard_cost_std = data['STANDARD_COST'].std()
print("STANDARD COST")
print("MEAN = " , standard_cost_mean)
print("MEDIAN = " , standard_cost_median)
print("SD = " , standard_cost_std)
print(" ")
list_price_mean = data['LIST_PRICE'].mean()
list_price_median = data['LIST_PRICE'].median()
list_price_std = data['LIST_PRICE'].std()
print("LIST PRICE")
print("MEAN = " , list_price_mean)
print("MEDIAN = " , list_price_median)
print("SD = " , list_price_std)
print(" ")
quantity_mean = data['QUANTITY'].mean()
quantity_median = data['QUANTITY'].median()
quantity_std = data['QUANTITY'].std()
print("QUANTITY")
print("MEAN = " , quantity_mean)
print("MEDIAN = " , quantity_median)
print("SD = " , quantity_std)

print(" ")
uni_categories = data.groupby('PRODUCT_ID')['PRODUCT_ID'].count()
print(uni_categories)
# Out:
# STANDARD COST
# MEAN =  765.520404676259
# MEDIAN =  582.02
# SD =  794.2521419227027
#
# LIST PRICE
# MEAN =  950.9933273381293
# MEDIAN =  744.98
# SD =  991.0704822414887
#
# QUANTITY
# MEAN =  107.4748201438849
# MEDIAN =  98.0
# SD =  68.00841330229383
#
# PRODUCT_ID
# 2      6
# 3      9
# 4      9
# 5      9
# 6      9
#       ..
# 284    5
# 285    5
# 286    5
# 287    1
# 288    1
# Name: PRODUCT_ID, Length: 208, dtype: int64

# %% [markdown]
# 3. Category Analysis

# %%
hardware.plot(kind='bar', color='lightpink')
plt.xlabel('')
plt.ylabel('Number of Products')
plt.title('COMPUTER PARTS', fontweight='bold', color='black')
plt.xticks(rotation = 0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The Computer parts with the highest number of Products is Storage

# %% [markdown]
# 4. Cost and Price Analysis:

# %%
standard_cost_average = data['STANDARD_COST'].mean()
list_price_average = data['LIST_PRICE'].mean()

highest_standard_cost =  data.loc[data['STANDARD_COST'].idxmax(), 'PRODUCT_NAME']
highest_list_price = data.loc[data['LIST_PRICE'].idxmax(), 'PRODUCT_NAME']

print("Calculation on the Average Standard Cost = " , standard_cost_average)
print("Calculation on the Average List Price    =  " , list_price_average)
print(" ")
print("The Highest Standard Cost Product is" , highest_standard_cost)
print("The Highest List Price Product is ", highest_list_price)
# Out:
# Calculation on the Average Standard Cost =  765.520404676259
# Calculation on the Average List Price    =   950.9933273381293
#
# The Highest Standard Cost Product is Intel SSDPECME040T401
# The Highest List Price Product is  Intel SSDPECME040T401

# %% [markdown]
# 5. Location Analysis:

# %%
loc_city = data.groupby('CITY')['QUANTITY'].sum()
highest_city = city.idxmax()

loc_state = data.groupby('STATE')['QUANTITY'].sum()
highest_state = state.idxmax()

print("The location City with the highest quantity of products in stock is " , highest_city)
print(loc_city)
print(" ")
print("The location State with the highest quantity of products in stock is " , highest_state)
print(loc_state)
# Out:
# The location City with the highest quantity of products in stock is  South San Francisco
# CITY
# Beijing                13482
# Bombay                  7357
# Monterrey               9039
# Seattle                14860
# South Brunswick         7252
# South San Francisco    28613
# Southlake               5483
# Sydney                 20457
# Toronto                12969
# Name: QUANTITY, dtype: int64
#
# The location State with the highest quantity of products in stock is  California
# STATE
# California         28613
# Maharashtra         7357
# New Jersey          7252
# New South Wales    20457
# Nuevo León          9039
# Ontario            12969
# Shenzhen           13482
# Texas               5483
# Washington         14860
# Name: QUANTITY, dtype: int64

# %% [markdown]
# 6. Insights and Reporting:

# %%
report = """
Analysis Report

            The dataset named hardwareStore.csv contains thousands of pieces of information
        spread across twenty-two (22) columns representing different categories of data.
        Manual computation of mean, median, and standard deviation is challenging due to
        the large dataset size, so I utilized the functions .mean, .median, and .std to
        automatically derive these statistical measures. The bar graph illustrates the
        highest-selling computer parts. It provides evidence of the products with the
        highest quantities and computes the standard cost and list price. Moreover, it
        identifies the cities and states with the highest quantity of products in stock.
        These calculations ensure reliable and trustworthy computations, simplifying the
        analysis process.
"""

print(report)
# Out:
# Analysis Report
#
#             The dataset named hardwareStore.csv contains thousands of pieces of information
#         spread across twenty-two (22) columns representing different categories of data.
#         Manual computation of mean, median, and standard deviation is challenging due to
#         the large dataset size, so I utilized the functions .mean, .median, and .std to
#         automatically derive these statistical measures. The bar graph illustrates the
#         highest-selling computer parts. It provides evidence of the products with the
#         highest quantities and computes the standard cost and list price. Moreover, it
#         identifies the cities and states with the highest quantity of products in stock.
#         These calculations ensure reliable and trustworthy computations, simplifying the
#         analysis process.

# %%
with open('MacasaetReport.txt','w') as f:
  f.write(report)
